# %%
# ==============================
# DATA MANIPULATION
# ==============================
import pandas as pd
import numpy as np

# ==============================
# VISUALIZATION
# ==============================
import matplotlib.pyplot as plt
import seaborn as sns

# configuración opcional de gráficos
plt.style.use("default")
sns.set_theme()

print("Entorno listo 🚀")
# Out:
# Entorno listo 🚀

# %%
df = pd.read_csv("CSV\produccin-de-pozos-de-gas-y-petrleo-2026.csv")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\nacho\AppData\Local\Temp\ipykernel_29324\271021291.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv("CSV\produccin-de-pozos-de-gas-y-petrleo-2026.csv")
#   idempresa  anio  mes  idpozo  prod_pet  prod_gas  prod_agua  iny_agua  \
# 0       YPF  2026    1  135745      0.00      0.00       0.00       0.0
# 1       YPF  2026    1  161372    597.80    189.29     119.32       0.0
# 2       YPF  2026    1     742      0.00      0.00       0.00       0.0
# 3       YPF  2026    1  161371    673.85    220.69      96.85       0.0
# 4       YPF  2026    1   77613      0.00      0.00       0.00       0.0
#
#    iny_gas  iny_co2  ...  idareayacimiento                  areayacimiento  \
# 0      0.0      0.0  ...              Y036                       CCyB-17/B
# 1      0.0      0.0  ...              LCLL                LOMA CAMPANA-LLL
# ...
